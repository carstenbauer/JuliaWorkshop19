# %% [markdown]
# # Forward Mode Automatic Differentiation

# %% [markdown]
# At the heart of modern machine learning, so popular in 2019, is an optimization problem. Optimization means gradients, so suddenly differentiation, especially automatic differentiation (AD), is exciting.
#
# The first time one hears about AD, it is easy to imagine what it is. Surely it is straightforward symbolic differentiation applied to code. One imagines automatically doing what is learned in a calculus class, like
# $$ \frac{d}{dx}x^n = n x^{n-1}. $$
# **This is not how AD works.**
#
# Ok, then it must be numerical differentiation and to first order
# $$ \frac{df}{dx} \approx \frac{f(x+h) - f(x)}{\Delta h} $$
# **This is also not how AD works.**

# %% [markdown]
# # Babylonian sqrt

# %% [markdown]
# > Repeat $t \leftarrow (t + x/2)/2$ until $t$ converges to $\sqrt{x}$.

# %%
@inline function Babylonian(x; N = 10)
    t = (1+x)/2
    for i = 2:N
        t = (t + x/t)/2
    end
    t
end
# Out:
# Babylonian (generic function with 1 method)

# %%
α = π

Babylonian(α), √α
# Out:
# (1.7724538509055159, 1.7724538509055159)

# %%
Babylonian(2), √2
# Out:
# (1.414213562373095, 1.4142135623730951)

# %%
using PyPlot

xs = 0:0.01:49

for i in 1:5
    plot(xs, [Babylonian(x; N=i) for x in xs], label="Iteration $i")
end

plot(xs, sqrt.(xs), label="sqrt", color="black")

legend()
title("Those Babylonians really knew how to √")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0.5, 1.0, 'Those Babylonians really knew how to √')

# %% [markdown]
# # ... and now the derivative, almost by magic

# %% [markdown]
# Ten lines of Julia code! No mention of 1/2 over sqrt(x). D for "dual number", invented by Clifford in 1873.

# %%
struct D <: Number
    x::Float64 # value
    ϵ::Float64 # derivative
end

import Base: +, /, convert, promote_rule
a::D + b::D = D(a.x + b.x, a.ϵ + b.ϵ) # sum rule
a::D / b::D = D(a.x / b.x, (b.x * a.ϵ - a.x * b.ϵ)/b.x^2) # quotient rule
convert(::Type{D}, x::Real) = D(x, zero(x))
promote_rule(::Type{D}, ::Type{<:Number}) = D
# Out:
# promote_rule (generic function with 137 methods)

# %% [markdown]
# The same babylonian algorithm with no rewrite at all computes properly the derivative as the check shows.

# %%
Babylonian(D(5, 1)) |> dump
# Out:
# D
#   x: Float64 2.23606797749979
#   ϵ: Float64 0.22360679774997896

# %%
x = 5; Babylonian(D(x, 1)), (√x, 0.5 / √x)
# Out:
# (D(2.23606797749979, 0.22360679774997896), (2.23606797749979, 0.22360679774997896))

# %%
x = π; Babylonian(D(x, 1)), (√x, 0.5 / √x)
# Out:
# (D(1.7724538509055159, 0.28209479177387814), (1.7724538509055159, 0.28209479177387814))

# %% [markdown]
# ### It just works!

# %%
code_llvm(Babylonian, (D,); debuginfo=:none)
# Out:
# ; Function Attrs: uwtable
# define void @julia_Babylonian_14165({ double, double }* noalias nocapture sret, { double, double } addrspace(11)* nocapture nonnull readonly dereferenceable(16)) #0 {
# top:
#   %2 = getelementptr inbounds { double, double }, { double, double } addrspace(11)* %1, i64 0, i32 0
#   %3 = load double, double addrspace(11)* %2, align 8
#   %4 = fadd double %3, 1.000000e+00
#   %5 = getelementptr inbounds { double, double }, { double, double } addrspace(11)* %1, i64 0, i32 1
#   %6 = load double, double addrspace(11)* %5, align 8
#   %7 = fadd double %6, 0.000000e+00
#   %8 = fmul double %4, 5.000000e-01
#   %9 = fmul double %7, 2.000000e+00
#   %10 = fmul double %4, 0.000000e+00
#   %11 = fsub double %9, %10
#   %12 = fmul double %11, 2.500000e-01
#   %13 = fdiv double %3, %8
#   %14 = fmul double %8, %6
#   %15 = fmul double %12, %3
#   %16 = fsub double %14, %15
#   %17 = fmul double %8, %8
#   %18 = fdiv double %16, %17
#   %19 = fadd double %8, %13
#   %20 = fadd double %12, %18
#   %21 = fmul double %19, 5.000000e-01
#   %22 = fmul double %20, 2.000000e+00
#   %23 = fmul double %19, 0.000000e+00
#   %24 = fsub double %22, %23
#   %25 = fmul double %24, 2.500000e-01
#   %26 = fdiv double %3, %21
#   %27 = fmul double %21, %6
#   %28 = fmul double %25, %3
#   %29 = fsub double %27, %28
#   %30 = fmul double %21, %21
#   %31 = fdiv double %29, %30
#   %32 = fadd double %21, %26
#   %33 = fadd double %25, %31
#   %34 = fmul double %32, 5.000000e-01
#   %35 = fmul double %33, 2.000000e+00
#   %36 = fmul double %32, 0.000000e+00
#   %37 = fsub double %35, %36
#   %38 = fmul double %37, 2.500000e-01
#   %39 = fdiv double %3, %34
#   %40 = fmul double %34, %6
#   %41 = fmul double %38, %3
#   %42 = fsub double %40, %41
#   %43 = fmul double %34, %34
#   %44 = fdiv double %42, %43
#   %45 = fadd double %34, %39
#   %46 = fadd double %38, %44
#   %47 = fmul double %45, 5.000000e-01
#   %48 = fmul double %46, 2.000000e+00
#   %49 = fmul double %45, 0.000000e+00
#   %50 = fsub double %48, %49
#   %51 = fmul double %50, 2.500000e-01
#   %52 = fdiv double %3, %47
#   %53 = fmul double %47, %6
#   %54 = fmul double %51, %3
#   %55 = fsub double %53, %54
#   %56 = fmul double %47, %47
#   %57 = fdiv double %55, %56
#   %58 = fadd double %47, %52
#   %59 = fadd double %51, %57
#   %60 = fmul double %58, 5.000000e-01
#   %61 = fmul double %59, 2.000000e+00
#   %62 = fmul double %58, 0.000000e+00
#   %63 = fsub double %61, %62
#   %64 = fmul double %63, 2.500000e-01
#   %65 = fdiv double %3, %60
#   %66 = fmul double %60, %6
#   %67 = fmul double %64, %3
#   %68 = fsub double %66, %67
#   %69 = fmul double %60, %60
#   %70 = fdiv double %68, %69
#   %71 = fadd double %60, %65
#   %72 = fadd double %64, %70
#   %73 = fmul double %71, 5.000000e-01
#   %74 = fmul double %72, 2.000000e+00
#   %75 = fmul double %71, 0.000000e+00
#   %76 = fsub double %74, %75
#   %77 = fmul double %76, 2.500000e-01
#   %78 = fdiv double %3, %73
#   %79 = fmul double %73, %6
#   %80 = fmul double %77, %3
#   %81 = fsub double %79, %80
#   %82 = fmul double %73, %73
#   %83 = fdiv double %81, %82
#   %84 = fadd double %73, %78
#   %85 = fadd double %77, %83
#   %86 = fmul double %84, 5.000000e-01
#   %87 = fmul double %85, 2.000000e+00
#   %88 = fmul double %84, 0.000000e+00
#   %89 = fsub double %87, %88
#   %90 = fmul double %89, 2.500000e-01
#   %91 = fdiv double %3, %86
#   %92 = fmul double %86, %6
#   %93 = fmul double %90, %3
#   %94 = fsub double %92, %93
#   %95 = fmul double %86, %86
#   %96 = fdiv double %94, %95
#   %97 = fadd double %86, %91
#   %98 = fadd double %90, %96
#   %99 = fmul double %97, 5.000000e-01
#   %100 = fmul double %98, 2.000000e+00
#   %101 = fmul double %97, 0.000000e+00
#   %102 = fsub double %100, %101
#   %103 = fmul double %102, 2.500000e-01
#   %104 = fdiv double %3, %99
#   %105 = fmul double %99, %6
#   %106 = fmul double %103, %3
#   %107 = fsub double %105, %106
#   %108 = fmul double %99, %99
#   %109 = fdiv double %107, %108
#   %110 = fadd double %99, %104
#   %111 = fadd double %103, %109
#   %112 = fmul double %110, 5.000000e-01
#   %113 = fmul double %111, 2.000000e+00
#   %114 = fmul double %110, 0.000000e+00
#   %115 = fsub double %113, %114
#   %116 = fmul double %115, 2.500000e-01
#   %117 = fdiv double %3, %112
#   %118 = fmul double %112, %6
#   %119 = fmul double %116, %3
#   %120 = fsub double %118, %119
#   %121 = fmul double %112, %112
#   %122 = fdiv double %120, %121
#   %123 = fadd double %112, %117
#   %124 = fadd double %116, %122
#   %125 = fmul double %124, 2.000000e+00
#   %126 = fmul double %123, 0.000000e+00
#   %127 = fsub double %125, %126
#   %128 = insertelement <2 x double> <double 5.000000e-01, double undef>, double %127, i32 1
#   %129 = insertelement <2 x double> <double undef, double 2.500000e-01>, double %123, i32 0
#   %130 = fmul <2 x double> %128, %129
#   %131 = bitcast { double, double }* %0 to <2 x double>*
#   store <2 x double> %130, <2 x double>* %131, align 8
#   ret void
# }

# %% [markdown]
# # Symbolically

# %% [markdown]
# It may be of some value to understand that the below is mathematically equivalent, though not what the computation is doing.

# %%
using SymPy
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\carsten\.julia\compiled\v1.1\SymPy\KzewI.ji for SymPy [24249f21-da20-56a4-8eb1-6a02cf4ae2e6]
# └ @ Base loading.jl:1184

# %%
x = symbols("x")

display("Iterations as a function of x")
for k = 1:5
    display(simplify(Babylonian(x; N=k)))
end

display("Derivatives as a function of x")
for k = 1:5
    display(simplify(diff(simplify(Babylonian(x; N=k)), x)))
end
# Out:
# "Iterations as a function of x"
# x   1
# - + -
# 2   2
#            2
#     (x + 1)
# x + --------
#        4
# ------------
#    x + 1
#  4       3       2
# x  + 28*x  + 70*x  + 28*x + 1
# -----------------------------
#      / 3      2          \
#    8*\x  + 7*x  + 7*x + 1/
#  8        7         6         5          4         3         2
# x  + 120*x  + 1820*x  + 8008*x  + 12870*x  + 8008*x  + 1820*x  + 120*x + 1
# --------------------------------------------------------------------------
#          / 7       6        5        4        3        2           \
#       16*\x  + 35*x  + 273*x  + 715*x  + 715*x  + 273*x  + 35*x + 1/
#  16        15          14           13             12             11
# x   + 496*x   + 35960*x   + 906192*x   + 10518300*x   + 64512240*x   + 2257928
# ------------------------------------------------------------------------------
#                / 15        14         13           12           11
#             32*\x   + 155*x   + 6293*x   + 105183*x   + 876525*x   + 4032015*x
#
#     10              9              8              7              6
# 40*x   + 471435600*x  + 601080390*x  + 471435600*x  + 225792840*x  + 64512240*
# ------------------------------------------------------------------------------
# 10             9             8             7             6            5
#    + 10855425*x  + 17678835*x  + 17678835*x  + 10855425*x  + 4032015*x  + 8765
#
#  5             4           3          2
# x  + 10518300*x  + 906192*x  + 35960*x  + 496*x + 1
# ---------------------------------------------------
#     4           3         2            \
# 25*x  + 105183*x  + 6293*x  + 155*x + 1/
# "Derivatives as a function of x"
# 1/2
#    2
#   x  + 2*x + 5
# ----------------
#   / 2          \
# 4*\x  + 2*x + 1/
#  6       5        4        3        2
# x  + 14*x  + 147*x  + 340*x  + 375*x  + 126*x + 21
# --------------------------------------------------
#   / 6       5       4        3       2           \
# 8*\x  + 14*x  + 63*x  + 100*x  + 63*x  + 14*x + 1/
#  14       13         12          11           10            9            8
# x   + 70*x   + 3199*x   + 52364*x   + 438945*x   + 2014506*x  + 5430215*x  + 8
# ------------------------------------------------------------------------------
#       / 14       13         12          11           10           9
#    16*\x   + 70*x   + 1771*x   + 20540*x   + 126009*x   + 440986*x  + 920795*x
#
#         7            6            5            4           3          2
# 836200*x  + 8842635*x  + 5425210*x  + 2017509*x  + 437580*x  + 52819*x  + 3094
# ------------------------------------------------------------------------------
# 8            7           6           5           4          3         2
#   + 1173960*x  + 920795*x  + 440986*x  + 126009*x  + 20540*x  + 1771*x  + 70*x
#
#
# *x + 85
# -------
#     \
#  + 1/
#  30        29          28            27              26               25
# x   + 310*x   + 59799*x   + 4851004*x   + 215176549*x   + 5809257090*x   + 102
# ------------------------------------------------------------------------------
#                      / 30        29          28            27             26
#                   32*\x   + 310*x   + 36611*x   + 2161196*x   + 73961629*x   +
#
#            24                  23                   22                   21
# 632077611*x   + 1246240871640*x   + 10776333438765*x   + 68124037776390*x   +
# ------------------------------------------------------------------------------
#              25                24                 23                  22
#  1603620018*x   + 23367042639*x   + 238538538360*x   + 1758637118685*x   + 957
#
#                  20                     19                     18
# 321156247784955*x   + 1146261110726340*x   + 3133113888931089*x   + 6614351291
# ------------------------------------------------------------------------------
#             21                   20                    19                    1
# 9944198310*x   + 39232152623175*x   + 122387258419860*x   + 293729420641881*x
#
#         17                      16                      15
# 211874*x   + 10850143060249839*x   + 13883516068991952*x   + 13883516369532147
# ------------------------------------------------------------------------------
# 8                    17                    16                    15
#   + 546274556891506*x   + 791156255418003*x   + 894836006026128*x   + 79115625
#
#   14                      13                     12                     11
# *x   + 10850142795067314*x   + 6614351497464949*x   + 3133113747810564*x   + 1
# ------------------------------------------------------------------------------
#          14                    13                    12                    11
# 5418003*x   + 546274556891506*x   + 293729420641881*x   + 122387258419860*x
#
#                  10                    9                   8
# 146261195398655*x   + 321156203432790*x  + 68124057936465*x  + 10776325550040*
# ------------------------------------------------------------------------------
#                   10                  9                  8                 7
# + 39232152623175*x   + 9579944198310*x  + 1758637118685*x  + 238538538360*x  +
#
#  7                  6                 5               4              3
# x  + 1246243501215*x  + 102631341330*x  + 5809427001*x  + 215145084*x  + 48554
# ------------------------------------------------------------------------------
#               6               5             4            3          2
#  23367042639*x  + 1603620018*x  + 73961629*x  + 2161196*x  + 36611*x  + 310*x
#
#     2
# 99*x  + 59334*x + 341
# ---------------------
#    \
# + 1/

# %% [markdown]
# How does AD get the answer?

# %% [markdown]
# Note that we can rewrite our algorithm by taking the derivative of every operation to obtain the correct result.

# %%
function dBabylonian(x; N=10)
    t = (1+x)/2
    dt = 1/2
    for i = 2:N
        t = (t + x/t)/2
        dt = (dt + (t-x*dt)/t^2)/2;
    end
    dt
end
# Out:
# dBabylonian (generic function with 1 method)

# %%
dBabylonian(5), 0.5/√5
# Out:
# (0.22360679774997896, 0.22360679774997896)

# %% [markdown]
# So, basically the trick is for the computer system to do the rewrite for you, without any loss of speed or convenience.

# %% [markdown]
# Important: The derivative is substituted *before* the JIT compilation, and thus efficient compiled code is executed.

# %% [markdown]
# # ForwardDiff.jl

# %%
# utility function for our small forward AD
derivative(f::Function, x::Number) = f(D(x, one(x))).ϵ
# Out:
# derivative (generic function with 1 method)

# %%
derivative(Babylonian, 2)
# Out:
# 0.35355339059327373

# %%
derivative(x -> 1/x, 4), -1/4^2
# Out:
# (-0.0625, -0.0625)

# %% [markdown]
# Now that we have understood how forward AD works, we can use the more feature complete package [ForwardDiff.jl](https://github.com/JuliaDiff/ForwardDiff.jl).

# %%
using ForwardDiff

# %%
ForwardDiff.derivative(Babylonian, 2)
# Out:
# 0.35355339059327373

# %%
@edit ForwardDiff.derivative(Babylonian, 2)

# %% [markdown]
# (Note: [DiffRules.jl](https://github.com/JuliaDiff/DiffRules.jl))

# %% [markdown]
# **Example**: pressure = - d/dV(free energy)

# %% [markdown]
# # Some nice reads

# %% [markdown]
# Blog posts:
#
# * ML in Julia: https://julialang.org/blog/2018/12/ml-language-compiler
#
# * Nice example: https://fluxml.ai/2019/03/05/dp-vs-rl.html
#
# * Nice interactive examples: https://fluxml.ai/experiments/
#
# * Why Julia for ML? https://julialang.org/blog/2017/12/ml&pl
#
# * Neural networks with differential equation layers: https://julialang.org/blog/2019/01/fluxdiffeq
#
# Repositories:
#
# * AD flavors, like forward and reverse mode AD: https://github.com/MikeInnes/diff-zoo (Mike is one of the smartest Julia ML heads)
#
# Talks:
#
# * AD is a compiler problem: https://juliacomputing.com/assets/pdf/CGO_C4ML_talk.pdf
