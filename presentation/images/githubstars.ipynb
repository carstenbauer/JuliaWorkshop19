# %%
data = [2011.550158818044 1303.3592493297583;
2013.9842569984232 2550.466487935657;
2014.6522831915142 3895.3860589812284;
2015.3924186047939 5191.399463806967;
2016.2606602106734 6560.7721179624605;
2017.064895690824 7807.879356568359;
2017.7689899141724 9103.892761394098;
2018.5876735418801 13212.010723860585;
2018.588478751664 11744.82573726541;
2018.6027390169386 14948.179624664874;
2018.6419527334187 16464.270777479887;
2018.7613519242213 17809.190348525462;
2018.9248685590885 19031.844504021443;
2019.0087096858301 19496.453083109915]
# Out:
# 14×2 Array{Float64,2}:
#  2011.55   1303.36
#  2013.98   2550.47
#  2014.65   3895.39
#  2015.39   5191.4
#  2016.26   6560.77
#  2017.06   7807.88
#  2017.77   9103.89
#  2018.59  13212.0
#  2018.59  11744.8
#  2018.6   14948.2
#  2018.64  16464.3
#  2018.76  17809.2
#  2018.92  19031.8
#  2019.01  19496.5

# %%
years = data[:,1]
#stars = data[:,2]
stars = [1230, 2550, 3840, 5130, 6450, 7740, 9030, 10350, 11640, 14250, 15540, 16830, 18150, 19472]
# Out:
# 14-element Array{Int64,1}:
#   1230
#   2550
#   3840
#   5130
#   6450
#   7740
#   9030
#  10350
#  11640
#  14250
#  15540
#  16830
#  18150
#  19472

# %%
using Plots

# %%
plot(years, stars, marker=:circle, legend=false, framestyle=:asd)
